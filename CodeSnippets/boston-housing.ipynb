# %%
# the classic boston housing price dataset

# %%
import matplotlib.pyplot as plt
import numpy as np 
import os

# %%
H = np.loadtxt(os.path.join('DATA', 'housing.data'))
b = H[:, -1] # target variable
A = H[:, :-1] # features

# %%
# padding A with ones to make sure that our model has the option to have a non-zero intercept
A = np.pad(A, ((0, 0), (0, 1)), 'constant', constant_values=1)

# %%
b.shape, A.shape
# Out:
# ((506,), (506, 14))

# %%
U, S, VT = np.linalg.svd(A, full_matrices=False)
X = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b

# %%
U.shape
# Out:
# (506, 14)

# %%
# visualize S
plt.figure(figsize=(5, 5))
plt.imshow(np.diag(S))
plt.show()

# %%
# plot A and b
plt.figure(figsize=(5, 5))
plt.scatter(A[:, 0], b, marker='x', color='red')
plt.show()

# %%
data_tuple_list = [(i, j) for i,j in zip(A, b)]

# %%
len(data_tuple_list)
# Out:
# 506

# %%
# sort data tuple list by the second element in each tuple
data_tuple_list.sort(key=lambda x: x[1])

# %%
prices = [x[1] for x in data_tuple_list]

# %%
# plot prices vs index
plt.figure(figsize=(5, 5))
plt.scatter(range(len(prices)), prices, marker='x', color='red')
