# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
A= np.loadtxt(os.path.join( "DATA", "hald_ingredients.csv"), delimiter=",")
b = np.loadtxt(os.path.join( "DATA", "hald_heat.csv"), delimiter=",")

# %%
U, S, VT = np.linalg.svd(A, full_matrices=False)
X = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b

# %%
plt.plot(b, label="heat data")
plt.plot(A@X, "-o", label="regression")
plt.legend()

# %%
# note: not all of the data is used for the regression irl, this is just an example, and we are not splitting it into training and testings sets
