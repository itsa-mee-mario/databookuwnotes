# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
A = imread('a.jpg')

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
plt.imshow(A)

# %%
X = np.mean(A, -1) # convert rgb to greyscale by taking the average of the three channels
X = torch.tensor(X

# %%
U, S, V = torch.linalg.svd(X, full_matrices=False)
S = np.diag(S)
img = plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
# Out:
# (-0.5, 5779.5, 3999.5, -0.5)

# %%
j = 0
for r in (5, 20, 50, 100):
    Xapprox = U[:,:r] @ S[:r,:r] @ V[:r,:]
    plt.figure(j+1)
    j+=1
    img = plt.imshow(Xapprox)
    img.set_cmap('gray')
    plt.axis('off')
    plt.show()

# %%
plt.figure(1)
plt.semilogy(np.diag(S))
plt.title('Singular values')
plt.show()


plt.figure(2)
plt.plot(np.cumsum(np.diag(S))/np.sum(np.diag(S)))
plt.title('Cumulative sum of singular values')
plt.show()

# %%
X = torch.tensor(X)

# %%
import seaborn as sns

# %%
corr1, corr2 = X@ X.T, X.T @ X

# %%
plt.figure(3)
sns.heatmap(corr1)
plt.show()

# %%
plt.figure(4)
sns.heatmap(corr2)
plt.show()

# %%
corr1.size()
# Out:
# torch.Size([4000, 4000])

# %%
corr2.size()
# Out:
# torch.Size([5780, 5780])

# %%
X.size()
# Out:
# torch.Size([4000, 5780])
